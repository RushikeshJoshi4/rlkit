# %%
from gym.envs.mujoco import hopper_v3
# import gym.envs.mujoco.hopper_v3
import rlkit.torch.pytorch_util as ptu
from rlkit.data_management.env_replay_buffer import EnvReplayBuffer
from rlkit.envs.wrappers import NormalizedBoxEnv
from rlkit.launchers.launcher_util import setup_logger
from rlkit.samplers.data_collector import MdpPathCollector
from rlkit.torch.sac.policies import TanhGaussianPolicy, MakeDeterministic
from rlkit.torch.sac.sac import SACTrainer
from rlkit.torch.networks import FlattenMlp
from rlkit.torch.torch_rl_algorithm import TorchBatchRLAlgorithm

import abc
from collections import OrderedDict

import gtimer as gt
import torch
import os
import copy

from rlkit.core import logger, eval_util
from rlkit.data_management.replay_buffer import ReplayBuffer
from rlkit.samplers.data_collector import DataCollector

import abc
import torch
import gtimer as gt
from rlkit.core.rl_algorithm import BaseRLAlgorithm
from rlkit.data_management.replay_buffer import ReplayBuffer
from rlkit.samplers.data_collector import PathCollector

# %%
# import torch

# %%
variant = dict(
    algorithm="SAC",
    version="normal",
    layer_size=256,
    replay_buffer_size=int(1E6),
    algorithm_kwargs=dict(
        num_epochs=1,
        num_eval_steps_per_epoch=5000,
        num_trains_per_train_loop=1000,
        num_expl_steps_per_train_loop=1000,
        min_num_steps_before_training=1000,
        max_path_length=1000,
        batch_size=256,
    ),
    trainer_kwargs=dict(
        discount=0.99,
        soft_target_tau=5e-3,
        target_update_period=1,
        policy_lr=3E-4,
        qf_lr=3E-4,
        reward_scale=1,
        use_automatic_entropy_tuning=True,
    ),
)
setup_logger('experiment-7', variant=variant)
ptu.set_gpu_mode(True, 0)

expl_env = hopper_v3.HopperEnv()
eval_env = hopper_v3.HopperEnv()


expl_env = NormalizedBoxEnv(expl_env)
eval_env = NormalizedBoxEnv(eval_env)
obs_dim = expl_env.observation_space.low.size
action_dim = eval_env.action_space.low.size
# print(obs_dim, action_dim)
# Out:
# /home/rushikej/Desktop/tmp/gym/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
# ckpt_path = 'ckpt.pkl'
# checkpoint = torch.load(ckpt_path)
# model.load_state_dict(checkpoint['model_state_dict'])
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# epoch = checkpoint['epoch']
# loss = checkpoint['loss']

# %%
# ckpt_path = 'ckpt.pkl'
# checkpoint = torch.load(ckpt_path)

# %%
M = variant['layer_size']
qf1 = FlattenMlp(
    input_size=obs_dim + action_dim,
    output_size=1,
    hidden_sizes=[M, M],
)
qf2 = FlattenMlp(
    input_size=obs_dim + action_dim,
    output_size=1,
    hidden_sizes=[M, M],
)
target_qf1 = FlattenMlp(
    input_size=obs_dim + action_dim,
    output_size=1,
    hidden_sizes=[M, M],
)
target_qf2 = FlattenMlp(
    input_size=obs_dim + action_dim,
    output_size=1,
    hidden_sizes=[M, M],
)
policy = TanhGaussianPolicy(
    obs_dim=obs_dim,
    action_dim=action_dim,
    hidden_sizes=[M, M],
)
eval_policy = MakeDeterministic(policy)
eval_path_collector = MdpPathCollector(
    eval_env,
    eval_policy,
)
expl_path_collector = MdpPathCollector(
    expl_env,
    policy,
)
replay_buffer = EnvReplayBuffer(
    variant['replay_buffer_size'],
    expl_env,
)
trainer = SACTrainer(
    env=eval_env,
    policy=policy,
    qf1=qf1,
    qf2=qf2,
    target_qf1=target_qf1,
    target_qf2=target_qf2,
    **variant['trainer_kwargs']
)
# Out:
# starting super init
# super done
# assigning done
# calculating np.prod term
# thats done
# initializing alpha optimizer
# thats done
# auto entropy thing done
# criterions done
# optimizers done
# done

# %%
# # run this whenever rlkit is changed
# import rlkit.torch.pytorch_util as ptu
# from rlkit.data_management.env_replay_buffer import EnvReplayBuffer
# from rlkit.envs.wrappers import NormalizedBoxEnv
# from rlkit.launchers.launcher_util import setup_logger
# from rlkit.samplers.data_collector import MdpPathCollector
# from rlkit.torch.sac.policies import TanhGaussianPolicy, MakeDeterministic
# from rlkit.torch.sac.sac import SACTrainer
# from rlkit.torch.networks import FlattenMlp
# from rlkit.torch.torch_rl_algorithm import TorchBatchRLAlgorithm

# %%
# import importlib
# import rlkit
# importlib.reload(rlkit)
# from rlkit.torch.torch_rl_algorithm import TorchBatchRLAlgorithm

# %%
# from rlkit.core import logger, eval_util

# %%
# expl_paths = algorithm.expl_data_collector.get_epoch_paths()
# d = eval_util.get_generic_path_information(expl_paths)

# d['Rewards Mean']

# %%
import abc
from collections import OrderedDict

import gtimer as gt
import torch
import os
import copy

from rlkit.core import logger, eval_util
from rlkit.data_management.replay_buffer import ReplayBuffer
from rlkit.samplers.data_collector import DataCollector


def _get_epoch_timings():
    times_itrs = gt.get_times().stamps.itrs
    times = OrderedDict()
    epoch_time = 0
    for key in sorted(times_itrs):
        time = times_itrs[key][-1]
        epoch_time += time
        times['time/{} (s)'.format(key)] = time
    times['time/epoch (s)'] = epoch_time
    times['time/total (s)'] = gt.get_times().total
    return times


class BaseRLAlgorithm2(object, metaclass=abc.ABCMeta):
    def __init__(
            self,
            trainer,
            exploration_env,
            evaluation_env,
            exploration_data_collector: DataCollector,
            evaluation_data_collector: DataCollector,
            replay_buffer: ReplayBuffer,
            initial_epoch
    ):
        self.trainer = trainer
        self.expl_env = exploration_env
        self.eval_env = evaluation_env
        self.expl_data_collector = exploration_data_collector
        self.eval_data_collector = evaluation_data_collector
        self.replay_buffer = replay_buffer
        self._start_epoch = initial_epoch

        self.post_epoch_funcs = []

    def train(self, initial_epoch=0, epochs=None, dir_=None, exp_no=None):
        self._train(initial_epoch, epochs, dir_, exp_no)

    def _train(self):
        """
        Train model.
        """
        raise NotImplementedError('_train must implemented by inherited class')

    def get_cur_best_metric_val(self):
        cur_best_metric_val = None
        if os.path.exists('results/hopper/cur_best_avg_rewards.pkl'):
            cur_best_metric_val = copy.deepcopy(torch.load('results/hopper/cur_best_avg_rewards.pkl')['cur_best_metric_val'])
        else:
            cur_best_metric_val = -1* float('inf')
        return cur_best_metric_val

    def _end_epoch(self, epoch):
        print('in _end_epoch, epoch is: {}'.format(epoch))
        snapshot = self._get_snapshot()
        logger.save_itr_params(epoch, snapshot)
        # trainer_obj = self.trainer
        # ckpt_path='ckpt.pkl'
        # logger.save_ckpt(epoch, trainer_obj, ckpt_path)
        # gt.stamp('saving')
        if epoch%10==0:
            self.save_snapshot_2(epoch)
        eval_paths = self.eval_data_collector.get_epoch_paths()
        d = eval_util.get_generic_path_information(eval_paths)
        # print(d.keys())
        metric_val = d['Returns Mean']
        
        cur_best_metric_val = self.get_cur_best_metric_val()
        self.save_snapshot_2_best_only(metric_val=metric_val, cur_best_metric_val=cur_best_metric_val, min_or_max='max', epoch=epoch)
        self._log_stats(epoch)

        self.expl_data_collector.end_epoch(epoch)
        self.eval_data_collector.end_epoch(epoch)
        self.replay_buffer.end_epoch(epoch)
        self.trainer.end_epoch(epoch)

        for post_epoch_func in self.post_epoch_funcs:
            post_epoch_func(self, epoch)

    def save_snapshot_2(self, epoch):
        print('Saving snapshot 2')
        self_copy = copy.deepcopy(self)
        torch.save(copy.deepcopy({'algorithm':self_copy, 'epoch':epoch}), 'results/hopper/ckpt.pkl')

    def get_snapshot_2(self):
        print('in get_snapshot_2')
        ckpt = {}
        ckpt = torch.load('results/hopper/ckpt.pkl')
        self = copy.deepcopy(ckpt['algorithm'])
        epoch = ckpt['epoch']
        return epoch
    
    def get_snapshot_best(self):
        print('in get_snapshot_best')
        ckpt = None
        ckpt = torch.load('results/hopper/ckpt-best.pkl')
        self = copy.deepcopy(ckpt['algorithm'])
        epoch = ckpt['epoch']
        return epoch

    def save_snapshot_2_best_only(self, metric_val, cur_best_metric_val, min_or_max='min', epoch=0):
        if min_or_max == 'min' and metric_val < cur_best_metric_val \
            or min_or_max == 'max' and metric_val > cur_best_metric_val:
            print('Saving snapshot best')
            print(metric_val)
            print(cur_best_metric_val)
            self_copy = copy.deepcopy(self)
            torch.save({'algorithm':self_copy, 'epoch':epoch}, 'results/hopper/ckpt-best.pkl')
            cur_best_metric_val = metric_val
            cur_best_metric_val_copy = copy.deepcopy(cur_best_metric_val)
            torch.save({'cur_best_metric_val':cur_best_metric_val_copy}, 'results/hopper/cur_best_avg_rewards.pkl')

    # def _resume_training(self):

    def _get_snapshot(self):
        snapshot = {}
        for k, v in self.trainer.get_snapshot().items():
            snapshot['trainer/' + k] = v
        for k, v in self.expl_data_collector.get_snapshot().items():
            snapshot['exploration/' + k] = v
        for k, v in self.eval_data_collector.get_snapshot().items():
            snapshot['evaluation/' + k] = v
        for k, v in self.replay_buffer.get_snapshot().items():
            snapshot['replay_buffer/' + k] = v
        return snapshot

    def _log_stats(self, epoch):
        logger.log("Epoch {} finished".format(epoch), with_timestamp=True)

        """
        Replay Buffer
        """
        logger.record_dict(
            self.replay_buffer.get_diagnostics(),
            prefix='replay_buffer/'
        )

        """
        Trainer
        """
        logger.record_dict(self.trainer.get_diagnostics(), prefix='trainer/')

        """
        Exploration
        """
        logger.record_dict(
            self.expl_data_collector.get_diagnostics(),
            prefix='exploration/'
        )
        expl_paths = self.expl_data_collector.get_epoch_paths()
        if hasattr(self.expl_env, 'get_diagnostics'):
            logger.record_dict(
                self.expl_env.get_diagnostics(expl_paths),
                prefix='exploration/',
            )
        logger.record_dict(
            eval_util.get_generic_path_information(expl_paths),
            prefix="exploration/",
        )
        """
        Evaluation
        """
        logger.record_dict(
            self.eval_data_collector.get_diagnostics(),
            prefix='evaluation/',
        )
        eval_paths = self.eval_data_collector.get_epoch_paths()
        if hasattr(self.eval_env, 'get_diagnostics'):
            logger.record_dict(
                self.eval_env.get_diagnostics(eval_paths),
                prefix='evaluation/',
            )
        logger.record_dict(
            eval_util.get_generic_path_information(eval_paths),
            prefix="evaluation/",
        )

        """
        Misc
        """
        # gt.stamp('logging')
        logger.record_dict(_get_epoch_timings())
        logger.record_tabular('Epoch', epoch)
        logger.dump_tabular(with_prefix=False, with_timestamp=False, file_name='logs/hopper/log1.txt', file_name2='logs/hopper/log2')

    @abc.abstractmethod
    def training_mode(self, mode):
        """
        Set training mode to `mode`.
        :param mode: If True, training will happen (e.g. set the dropout
        probabilities to not all ones).
        """
        pass

# %%
import abc
import torch
import gtimer as gt
from rlkit.core.rl_algorithm import BaseRLAlgorithm
from rlkit.data_management.replay_buffer import ReplayBuffer
from rlkit.samplers.data_collector import PathCollector


class BatchRLAlgorithm2(BaseRLAlgorithm2, metaclass=abc.ABCMeta):
    def __init__(
            self,
            trainer,
            exploration_env,
            evaluation_env,
            exploration_data_collector: PathCollector,
            evaluation_data_collector: PathCollector,
            replay_buffer: ReplayBuffer,
            batch_size,
            max_path_length,
            num_epochs,
            num_eval_steps_per_epoch,
            num_expl_steps_per_train_loop,
            num_trains_per_train_loop,
            num_train_loops_per_epoch=1,
            min_num_steps_before_training=0,
            initial_epoch=0
    ):
        super().__init__(
            trainer,
            exploration_env,
            evaluation_env,
            exploration_data_collector,
            evaluation_data_collector,
            replay_buffer,
            initial_epoch
        )
        self.batch_size = batch_size
        self.max_path_length = max_path_length
        self.num_epochs = num_epochs
        self.num_eval_steps_per_epoch = num_eval_steps_per_epoch
        self.num_trains_per_train_loop = num_trains_per_train_loop
        self.num_train_loops_per_epoch = num_train_loops_per_epoch
        self.num_expl_steps_per_train_loop = num_expl_steps_per_train_loop
        self.min_num_steps_before_training = min_num_steps_before_training

    # def store_everything(self, ckpt_path):
    #     d = {
            
    #     }
    #     torch.save(d, ckpt_path)

    def _train(self, initial_epoch=0, epochs=None, dir_=None, exp_no=None):
        
        self._start_epoch = initial_epoch
        if epochs is not None: 
            self.num_epochs = epochs
        # print('\n\n\n\nn\n\n\n\nin _train #########')
        if self.min_num_steps_before_training > 0:
            init_expl_paths = self.expl_data_collector.collect_new_paths(
                self.max_path_length,
                self.min_num_steps_before_training,
                discard_incomplete_paths=False,
            )
            self.replay_buffer.add_paths(init_expl_paths)
            self.expl_data_collector.end_epoch(-1)
         
        # for epoch in gt.timed_for(
        #         range(self._start_epoch, self.num_epochs),
        #         save_itrs=True,
        # ):

        for epoch in range(self._start_epoch, self.num_epochs):

            self.eval_data_collector.collect_new_paths(
                self.max_path_length,
                self.num_eval_steps_per_epoch,
                discard_incomplete_paths=True,
            )
            # # gt.stamp('evaluation sampling')

            for _ in range(self.num_train_loops_per_epoch):
                new_expl_paths = self.expl_data_collector.collect_new_paths(
                    self.max_path_length,
                    self.num_expl_steps_per_train_loop,
                    discard_incomplete_paths=False,
                )
                # # gt.stamp('exploration sampling', unique=False)

                self.replay_buffer.add_paths(new_expl_paths)
                # # gt.stamp('data storing', unique=False)

                self.training_mode(True)
                for _ in range(self.num_trains_per_train_loop):
                    train_data = self.replay_buffer.random_batch(
                        self.batch_size)
                    self.trainer.train(train_data)
                # # gt.stamp('training', unique=False)
                self.training_mode(False)

            self._end_epoch(epoch)

# %%
import abc
from collections import OrderedDict

from typing import Iterable
from torch import nn as nn

from rlkit.core.batch_rl_algorithm import BatchRLAlgorithm
from rlkit.core.online_rl_algorithm import OnlineRLAlgorithm
from rlkit.core.trainer import Trainer
from rlkit.torch.core import np_to_pytorch_batch


class TorchOnlineRLAlgorithm(OnlineRLAlgorithm):
    def to(self, device):
        for net in self.trainer.networks:
            net.to(device)

    def training_mode(self, mode):
        for net in self.trainer.networks:
            net.train(mode)


class TorchBatchRLAlgorithm2(BatchRLAlgorithm2):

    def to(self, device):
        for net in self.trainer.networks:
            net.to(device)

    def training_mode(self, mode):
        for net in self.trainer.networks:
            net.train(mode)


class TorchTrainer(Trainer, metaclass=abc.ABCMeta):
    def __init__(self):
        self._num_train_steps = 0

    def train(self, np_batch):
        self._num_train_steps += 1
        batch = np_to_pytorch_batch(np_batch)
        self.train_from_torch(batch)

    def get_diagnostics(self):
        return OrderedDict([
            ('num train calls', self._num_train_steps),
        ])

    @abc.abstractmethod
    def train_from_torch(self, batch):
        pass

    @property
    @abc.abstractmethod
    def networks(self) -> Iterable[nn.Module]:
        pass

# %%
def get_snapshot_3():
    print('in get_snapshot_3')
    ckpt = {}
    ckpt = torch.load('results/hopper/ckpt.pkl')
    # self = copy.deepcopy(ckpt['algorithm'])
    epoch = ckpt['epoch']
    return epoch, copy.deepcopy(ckpt['algorithm'])

# %%
# algorithm = TorchBatchRLAlgorithm2(
#         trainer=trainer,
#         exploration_env=expl_env,
#         evaluation_env=eval_env,
#         exploration_data_collector=expl_path_collector,
#         evaluation_data_collector=eval_path_collector,
#         replay_buffer=replay_buffer,
#         **variant['algorithm_kwargs']
#     )

# %%
# algorithm.get_snapshot_2()

# %%
# type(algorithm)

# %%
resume = True
resume_from_best = False
algorithm = None
if not resume:
    algorithm = TorchBatchRLAlgorithm2(
        trainer=trainer,
        exploration_env=expl_env,
        evaluation_env=eval_env,
        exploration_data_collector=expl_path_collector,
        evaluation_data_collector=eval_path_collector,
        replay_buffer=replay_buffer,
        **variant['algorithm_kwargs']
    )
    algorithm.to(ptu.device)
    algorithm.train(initial_epoch=0, epochs=1000)
else:
#     algorithm = TorchBatchRLAlgorithm()
#     algorithm = TorchBatchRLAlgorithm2(
#         trainer=trainer,
#         exploration_env=expl_env,
#         evaluation_env=eval_env,
#         exploration_data_collector=expl_path_collector,
#         evaluation_data_collector=eval_path_collector,
#         replay_buffer=replay_buffer,
#         **variant['algorithm_kwargs']
#     )
    if not resume_from_best:
        initial_epoch, algorithm = get_snapshot_3()
        initial_epoch+=1
    else:
        initial_epoch, algorithm = get_snapshot_best()
        initial_epoch+=1
    algorithm.to(ptu.device)
    algorithm.train(initial_epoch=initial_epoch, epochs = 1000)
# Out:
# in _end_epoch, epoch is: 0
# Saving snapshot 2
# /home/rushikej/miniconda3/envs/tf_2/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type TanhGaussianPolicy. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/rushikej/miniconda3/envs/tf_2/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Linear. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/rushikej/miniconda3/envs/tf_2/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type FlattenMlp. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/rushikej/miniconda3/envs/tf_2/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type MakeDeterministic. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/rushikej/miniconda3/envs/tf_2/lib/python3.7/site-packages/torch/serialization.py:292: UserWarning: Couldn't retrieve source code for container of type MSELoss. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Saving snapshot best
# 169.01549317642537
# -inf
# in _end_epoch, epoch is: 1
# in _end_epoch, epoch is: 2
# in _end_epoch, epoch is: 3
# Saving snapshot best
# 171.97924326820058
# 169.01549317642537
# in _end_epoch, epoch is: 4
# Saving snapshot best
# 181.3280134172994
# 171.97924326820058
# in _end_epoch, epoch is: 5
# Saving snapshot best
# 203.66988498898883
# 181.3280134172994
# in _end_epoch, epoch is: 6
# Saving snapshot best
# 210.17804304645833
# 203.66988498898883
# in _end_epoch, epoch is: 7
# Saving snapshot best
# 217.79926190992913
# 210.17804304645833
# in _end_epoch, epoch is: 8
# Saving snapshot best
# 276.0039474261683
# 217.79926190992913
# in _end_epoch, epoch is: 9
# Saving snapshot best
# 653.408460397065
# 276.0039474261683
# in _end_epoch, epoch is: 10
# Saving snapshot 2
# in _end_epoch, epoch is: 11
# in _end_epoch, epoch is: 12
# Saving snapshot best
# 1017.2037058731867
# 653.408460397065
# in _end_epoch, epoch is: 13
# Saving snapshot best
# 1021.0946321261063
# 1017.2037058731867
# in _end_epoch, epoch is: 14
# in _end_epoch, epoch is: 15
# in _end_epoch, epoch is: 16
# in _end_epoch, epoch is: 17
# Saving snapshot best
# 1055.632335276421
# 1021.0946321261063
# in _end_epoch, epoch is: 18
# in _end_epoch, epoch is: 19
# in _end_epoch, epoch is: 20
# Saving snapshot 2
# in _end_epoch, epoch is: 21
# in _end_epoch, epoch is: 22
# in _end_epoch, epoch is: 23
# in _end_epoch, epoch is: 24
# in _end_epoch, epoch is: 25
# Saving snapshot best
# 1070.1275002795048
# 1055.632335276421
# in _end_epoch, epoch is: 26
# in _end_epoch, epoch is: 27
# in _end_epoch, epoch is: 28
# in _end_epoch, epoch is: 29
# in _end_epoch, epoch is: 30
# Saving snapshot 2
# in _end_epoch, epoch is: 31
# in _end_epoch, epoch is: 32
# in _end_epoch, epoch is: 33
# in _end_epoch, epoch is: 34
# in _end_epoch, epoch is: 35
# Saving snapshot best
# 1094.6566815663741
# 1070.1275002795048
# in _end_epoch, epoch is: 36
# in _end_epoch, epoch is: 37
# in _end_epoch, epoch is: 38
# in _end_epoch, epoch is: 39
# in _end_epoch, epoch is: 40
# Saving snapshot 2
# in _end_epoch, epoch is: 41
# in _end_epoch, epoch is: 42
# in _end_epoch, epoch is: 43
# in _end_epoch, epoch is: 44
# in _end_epoch, epoch is: 45
# in _end_epoch, epoch is: 46
# in _end_epoch, epoch is: 47
# in _end_epoch, epoch is: 48
# in _end_epoch, epoch is: 49
# in _end_epoch, epoch is: 50
# Saving snapshot 2
# in _end_epoch, epoch is: 51
# in _end_epoch, epoch is: 52
# in _end_epoch, epoch is: 53
# in _end_epoch, epoch is: 54
# in _end_epoch, epoch is: 55
# in _end_epoch, epoch is: 56
# in _end_epoch, epoch is: 57
# in _end_epoch, epoch is: 58
# in _end_epoch, epoch is: 59
# in _end_epoch, epoch is: 60
# Saving snapshot 2
# in _end_epoch, epoch is: 61
# in _end_epoch, epoch is: 62
# in _end_epoch, epoch is: 63
# in _end_epoch, epoch is: 64
# in _end_epoch, epoch is: 65
# in _end_epoch, epoch is: 66
# in _end_epoch, epoch is: 67
# in _end_epoch, epoch is: 68
# in _end_epoch, epoch is: 69
# in _end_epoch, epoch is: 70
# Saving snapshot 2
# in _end_epoch, epoch is: 71
# in _end_epoch, epoch is: 72
# in _end_epoch, epoch is: 73
# in _end_epoch, epoch is: 74
# in _end_epoch, epoch is: 75
# in _end_epoch, epoch is: 76
# in _end_epoch, epoch is: 77
# in _end_epoch, epoch is: 78
# in _end_epoch, epoch is: 79
# in _end_epoch, epoch is: 80
# Saving snapshot 2
# in _end_epoch, epoch is: 81
# in _end_epoch, epoch is: 82
# in _end_epoch, epoch is: 83
# in _end_epoch, epoch is: 84
# in _end_epoch, epoch is: 85
# in _end_epoch, epoch is: 86
# in _end_epoch, epoch is: 87
# in _end_epoch, epoch is: 88
# in _end_epoch, epoch is: 89
# in _end_epoch, epoch is: 90
# Saving snapshot 2
# in _end_epoch, epoch is: 91
# in _end_epoch, epoch is: 92
# Saving snapshot best
# 1115.8483189911058
# 1094.6566815663741
# in _end_epoch, epoch is: 93
# in _end_epoch, epoch is: 94
# in _end_epoch, epoch is: 95
# in _end_epoch, epoch is: 96
# in _end_epoch, epoch is: 97
# in _end_epoch, epoch is: 98
# in _end_epoch, epoch is: 99
# in _end_epoch, epoch is: 100
# Saving snapshot 2
# in _end_epoch, epoch is: 101
# in _end_epoch, epoch is: 102
# in _end_epoch, epoch is: 103
# in _end_epoch, epoch is: 104
# in _end_epoch, epoch is: 105
# in _end_epoch, epoch is: 106
# in _end_epoch, epoch is: 107
# in _end_epoch, epoch is: 108
# in _end_epoch, epoch is: 109
# in _end_epoch, epoch is: 110
# Saving snapshot 2
# in _end_epoch, epoch is: 111
# in _end_epoch, epoch is: 112
# in _end_epoch, epoch is: 113
# in _end_epoch, epoch is: 114
# in _end_epoch, epoch is: 115
# in _end_epoch, epoch is: 116
# in _end_epoch, epoch is: 117
# in _end_epoch, epoch is: 118
# in _end_epoch, epoch is: 119
# in _end_epoch, epoch is: 120
# Saving snapshot 2
# in _end_epoch, epoch is: 121
# in _end_epoch, epoch is: 122
# in _end_epoch, epoch is: 123
# in _end_epoch, epoch is: 124
# in _end_epoch, epoch is: 125
# in _end_epoch, epoch is: 126
# in _end_epoch, epoch is: 127
# in _end_epoch, epoch is: 128
# in _end_epoch, epoch is: 129
# in _end_epoch, epoch is: 130
# Saving snapshot 2
# in _end_epoch, epoch is: 131
# in _end_epoch, epoch is: 132
# in _end_epoch, epoch is: 133
# in _end_epoch, epoch is: 134
# in _end_epoch, epoch is: 135
# in _end_epoch, epoch is: 136
# in _end_epoch, epoch is: 137
# in _end_epoch, epoch is: 138
# in _end_epoch, epoch is: 139
# in _end_epoch, epoch is: 140
# Saving snapshot 2
# in _end_epoch, epoch is: 141
# in _end_epoch, epoch is: 142
# in _end_epoch, epoch is: 143
# in _end_epoch, epoch is: 144
# in _end_epoch, epoch is: 145
# in _end_epoch, epoch is: 146
# in _end_epoch, epoch is: 147
# in _end_epoch, epoch is: 148
# in _end_epoch, epoch is: 149
# in _end_epoch, epoch is: 150
# Saving snapshot 2
# in _end_epoch, epoch is: 151
# in _end_epoch, epoch is: 152
# in _end_epoch, epoch is: 153
# in _end_epoch, epoch is: 154
# in _end_epoch, epoch is: 155
# in _end_epoch, epoch is: 156
# in _end_epoch, epoch is: 157
# in _end_epoch, epoch is: 158
# in _end_epoch, epoch is: 159
# in _end_epoch, epoch is: 160
# Saving snapshot 2
# Saving snapshot best
# 1383.145890248223
# 1115.8483189911058
# in _end_epoch, epoch is: 161
# in _end_epoch, epoch is: 162
# in _end_epoch, epoch is: 163
# in _end_epoch, epoch is: 164
# in _end_epoch, epoch is: 165
# in _end_epoch, epoch is: 166
# in _end_epoch, epoch is: 167
# in _end_epoch, epoch is: 168
# in _end_epoch, epoch is: 169
# in _end_epoch, epoch is: 170
# Saving snapshot 2
# in _end_epoch, epoch is: 171
# in _end_epoch, epoch is: 172
# in _end_epoch, epoch is: 173
# in _end_epoch, epoch is: 174
# in _end_epoch, epoch is: 175
# in _end_epoch, epoch is: 176
# in _end_epoch, epoch is: 177
# in _end_epoch, epoch is: 178
# in _end_epoch, epoch is: 179
# in _end_epoch, epoch is: 180
# Saving snapshot 2
# in _end_epoch, epoch is: 181
# in _end_epoch, epoch is: 182
# in _end_epoch, epoch is: 183
# in _end_epoch, epoch is: 184
# in _end_epoch, epoch is: 185
# in _end_epoch, epoch is: 186
# in _end_epoch, epoch is: 187
# in _end_epoch, epoch is: 188
# in _end_epoch, epoch is: 189
# in _end_epoch, epoch is: 190
# Saving snapshot 2
# in _end_epoch, epoch is: 191
# in _end_epoch, epoch is: 192
# in _end_epoch, epoch is: 193
# in _end_epoch, epoch is: 194
# in _end_epoch, epoch is: 195
# in _end_epoch, epoch is: 196
# in _end_epoch, epoch is: 197
# in _end_epoch, epoch is: 198
# in _end_epoch, epoch is: 199
# in _end_epoch, epoch is: 200
# Saving snapshot 2
# in _end_epoch, epoch is: 201
# in _end_epoch, epoch is: 202
# in _end_epoch, epoch is: 203
# in _end_epoch, epoch is: 204
# in _end_epoch, epoch is: 205
# in _end_epoch, epoch is: 206
# in _end_epoch, epoch is: 207
# in _end_epoch, epoch is: 208
# in _end_epoch, epoch is: 209
# in _end_epoch, epoch is: 210
# Saving snapshot 2
# in _end_epoch, epoch is: 211
# in _end_epoch, epoch is: 212
# in _end_epoch, epoch is: 213
# in _end_epoch, epoch is: 214
# in _end_epoch, epoch is: 215
# in _end_epoch, epoch is: 216
# in _end_epoch, epoch is: 217
# in _end_epoch, epoch is: 218
# in _end_epoch, epoch is: 219
# in _end_epoch, epoch is: 220
# Saving snapshot 2
# in _end_epoch, epoch is: 221
# in _end_epoch, epoch is: 222
# in _end_epoch, epoch is: 223
# in _end_epoch, epoch is: 224
# in _end_epoch, epoch is: 225
# in _end_epoch, epoch is: 226
# in _end_epoch, epoch is: 227
# in _end_epoch, epoch is: 228
# in _end_epoch, epoch is: 229
# in _end_epoch, epoch is: 230
# Saving snapshot 2
# in _end_epoch, epoch is: 231
# in _end_epoch, epoch is: 232
# in _end_epoch, epoch is: 233
# in _end_epoch, epoch is: 234
# in _end_epoch, epoch is: 235
# in _end_epoch, epoch is: 236
# in _end_epoch, epoch is: 237
# Saving snapshot best
# 1828.7951534217777
# 1383.145890248223
# in _end_epoch, epoch is: 238
# Saving snapshot best
# 1937.1558560588485
# 1828.7951534217777
# in _end_epoch, epoch is: 239
# in _end_epoch, epoch is: 240
# Saving snapshot 2
# in _end_epoch, epoch is: 241
# in _end_epoch, epoch is: 242
# in _end_epoch, epoch is: 243
# in _end_epoch, epoch is: 244
# in _end_epoch, epoch is: 245
# in _end_epoch, epoch is: 246
# in _end_epoch, epoch is: 247
# in _end_epoch, epoch is: 248
# Saving snapshot best
# 2085.8937055166457
# 1937.1558560588485
# in _end_epoch, epoch is: 249
# in _end_epoch, epoch is: 250
# Saving snapshot 2
# in _end_epoch, epoch is: 251
# in _end_epoch, epoch is: 252
# in _end_epoch, epoch is: 253
# in _end_epoch, epoch is: 254
# in _end_epoch, epoch is: 255
# in _end_epoch, epoch is: 256
# in _end_epoch, epoch is: 257
# in _end_epoch, epoch is: 258
# in _end_epoch, epoch is: 259
# in _end_epoch, epoch is: 260
# Saving snapshot 2
# in _end_epoch, epoch is: 261
# in _end_epoch, epoch is: 262
# in _end_epoch, epoch is: 263
# in _end_epoch, epoch is: 264
# in _end_epoch, epoch is: 265
# in _end_epoch, epoch is: 266
# in _end_epoch, epoch is: 267
# in _end_epoch, epoch is: 268
# in _end_epoch, epoch is: 269
# in _end_epoch, epoch is: 270
# Saving snapshot 2
# in _end_epoch, epoch is: 271
# in _end_epoch, epoch is: 272
# in _end_epoch, epoch is: 273
# in _end_epoch, epoch is: 274
# in _end_epoch, epoch is: 275
# in _end_epoch, epoch is: 276
# in _end_epoch, epoch is: 277
# in _end_epoch, epoch is: 278
# in _end_epoch, epoch is: 279
# in _end_epoch, epoch is: 280
# Saving snapshot 2
# in _end_epoch, epoch is: 281
# in _end_epoch, epoch is: 282
# in _end_epoch, epoch is: 283
# in _end_epoch, epoch is: 284
# in _end_epoch, epoch is: 285
# Saving snapshot best
# 2209.832921602147
# 2085.8937055166457
# in _end_epoch, epoch is: 286
# in _end_epoch, epoch is: 287
# in _end_epoch, epoch is: 288
# in _end_epoch, epoch is: 289
# in _end_epoch, epoch is: 290
# Saving snapshot 2
# in _end_epoch, epoch is: 291
# in _end_epoch, epoch is: 292
# in _end_epoch, epoch is: 293
# in _end_epoch, epoch is: 294
# in _end_epoch, epoch is: 295
# in _end_epoch, epoch is: 296
# in _end_epoch, epoch is: 297
# in _end_epoch, epoch is: 298
# in _end_epoch, epoch is: 299
# in _end_epoch, epoch is: 300
# Saving snapshot 2
# in _end_epoch, epoch is: 301
# in _end_epoch, epoch is: 302
# in _end_epoch, epoch is: 303
# in _end_epoch, epoch is: 304
# in _end_epoch, epoch is: 305
# in _end_epoch, epoch is: 306
# in _end_epoch, epoch is: 307
# in _end_epoch, epoch is: 308
# in _end_epoch, epoch is: 309
# in _end_epoch, epoch is: 310
# Saving snapshot 2
# in _end_epoch, epoch is: 311
# in _end_epoch, epoch is: 312
# in _end_epoch, epoch is: 313
# in _end_epoch, epoch is: 314
# in _end_epoch, epoch is: 315
# in _end_epoch, epoch is: 316
# in _end_epoch, epoch is: 317
# in _end_epoch, epoch is: 318
# in _end_epoch, epoch is: 319
# in _end_epoch, epoch is: 320
# Saving snapshot 2
# in _end_epoch, epoch is: 321
# in _end_epoch, epoch is: 322
# in _end_epoch, epoch is: 323
# in _end_epoch, epoch is: 324
# in _end_epoch, epoch is: 325
# in _end_epoch, epoch is: 326
# in _end_epoch, epoch is: 327
# in _end_epoch, epoch is: 328
# in _end_epoch, epoch is: 329
# in _end_epoch, epoch is: 330
# Saving snapshot 2
# in _end_epoch, epoch is: 331
# in _end_epoch, epoch is: 332
# in _end_epoch, epoch is: 333
# in _end_epoch, epoch is: 334
# in _end_epoch, epoch is: 335
# in _end_epoch, epoch is: 336
# in _end_epoch, epoch is: 337
# in _end_epoch, epoch is: 338
# in _end_epoch, epoch is: 339
# in _end_epoch, epoch is: 340
# Saving snapshot 2
# in _end_epoch, epoch is: 341
# in _end_epoch, epoch is: 342
# Saving snapshot best
# 2557.538997855992
# 2209.832921602147
# in _end_epoch, epoch is: 343
# in _end_epoch, epoch is: 344
# in _end_epoch, epoch is: 345
# in _end_epoch, epoch is: 346
# in _end_epoch, epoch is: 347
# in _end_epoch, epoch is: 348
# Saving snapshot best
# 2591.0059549751572
# 2557.538997855992
# in _end_epoch, epoch is: 349
# in _end_epoch, epoch is: 350
# Saving snapshot 2
# in _end_epoch, epoch is: 351
# in _end_epoch, epoch is: 352
# in _end_epoch, epoch is: 353
# in _end_epoch, epoch is: 354
# in _end_epoch, epoch is: 355
# in _end_epoch, epoch is: 356
# in _end_epoch, epoch is: 357
# in _end_epoch, epoch is: 358
# in _end_epoch, epoch is: 359
# in _end_epoch, epoch is: 360
# Saving snapshot 2
# in _end_epoch, epoch is: 361
# in _end_epoch, epoch is: 362
# in _end_epoch, epoch is: 363
# in _end_epoch, epoch is: 364
# in _end_epoch, epoch is: 365
# in _end_epoch, epoch is: 366
# in _end_epoch, epoch is: 367
# in _end_epoch, epoch is: 368
# in _end_epoch, epoch is: 369
# in _end_epoch, epoch is: 370
# Saving snapshot 2
# in _end_epoch, epoch is: 371
# in _end_epoch, epoch is: 372
# in _end_epoch, epoch is: 373
# in _end_epoch, epoch is: 374
# in _end_epoch, epoch is: 375
# in _end_epoch, epoch is: 376
# in _end_epoch, epoch is: 377
# in _end_epoch, epoch is: 378
# in _end_epoch, epoch is: 379
# in _end_epoch, epoch is: 380
# Saving snapshot 2
# in _end_epoch, epoch is: 381
# in _end_epoch, epoch is: 382
# in _end_epoch, epoch is: 383
# in _end_epoch, epoch is: 384
# in _end_epoch, epoch is: 385
# in _end_epoch, epoch is: 386
# in _end_epoch, epoch is: 387
# Saving snapshot best
# 3293.2974381798003
# 2591.0059549751572
# in _end_epoch, epoch is: 388
# in _end_epoch, epoch is: 389
# in _end_epoch, epoch is: 390
# Saving snapshot 2
# Saving snapshot best
# 3365.2062468009512
# 3293.2974381798003
# in _end_epoch, epoch is: 391
# in _end_epoch, epoch is: 392
# in _end_epoch, epoch is: 393
# in _end_epoch, epoch is: 394
# in _end_epoch, epoch is: 395
# in _end_epoch, epoch is: 396
# in _end_epoch, epoch is: 397
# in _end_epoch, epoch is: 398
# in _end_epoch, epoch is: 399
# in _end_epoch, epoch is: 400
# Saving snapshot 2
# in _end_epoch, epoch is: 401
# Saving snapshot best
# 3365.5802223200335
# 3365.2062468009512
# in _end_epoch, epoch is: 402
# in _end_epoch, epoch is: 403
# in _end_epoch, epoch is: 404
# in _end_epoch, epoch is: 405
# in _end_epoch, epoch is: 406
# in _end_epoch, epoch is: 407
# in _end_epoch, epoch is: 408
# in _end_epoch, epoch is: 409
# Saving snapshot best
# 3415.80214904281
# 3365.5802223200335
# in _end_epoch, epoch is: 410
# Saving snapshot 2
# in _end_epoch, epoch is: 411
# in _end_epoch, epoch is: 412
# in _end_epoch, epoch is: 413
# in _end_epoch, epoch is: 414
# in _end_epoch, epoch is: 415
# in _end_epoch, epoch is: 416
# in _end_epoch, epoch is: 417
# in _end_epoch, epoch is: 418
# in _end_epoch, epoch is: 419
# Saving snapshot best
# 3422.152121409308
# 3415.80214904281
# in _end_epoch, epoch is: 420
# Saving snapshot 2
# Saving snapshot best
# 3460.4108590778487
# 3422.152121409308
# in _end_epoch, epoch is: 421
# in _end_epoch, epoch is: 422
# in _end_epoch, epoch is: 423
# in _end_epoch, epoch is: 424
# in _end_epoch, epoch is: 425
# in _end_epoch, epoch is: 426
# in _end_epoch, epoch is: 427
# in _end_epoch, epoch is: 428
# in _end_epoch, epoch is: 429
# in _end_epoch, epoch is: 430
# Saving snapshot 2
# in _end_epoch, epoch is: 431
# in _end_epoch, epoch is: 432
# in _end_epoch, epoch is: 433
# Saving snapshot best
# 3461.63141077624
# 3460.4108590778487
# in _end_epoch, epoch is: 434
# in _end_epoch, epoch is: 435
# in _end_epoch, epoch is: 436
# in _end_epoch, epoch is: 437
# Saving snapshot best
# 3487.5659236819934
# 3461.63141077624
# in _end_epoch, epoch is: 438
# in _end_epoch, epoch is: 439
# in _end_epoch, epoch is: 440
# Saving snapshot 2
# in _end_epoch, epoch is: 441
# in _end_epoch, epoch is: 442
# in _end_epoch, epoch is: 443
# in _end_epoch, epoch is: 444
# in _end_epoch, epoch is: 445
# in _end_epoch, epoch is: 446
# Saving snapshot best
# 3497.636490545723
# 3487.5659236819934
# in _end_epoch, epoch is: 447
# in _end_epoch, epoch is: 448
# Saving snapshot best
# 3539.937118086839
# 3497.636490545723
# in _end_epoch, epoch is: 449
# in _end_epoch, epoch is: 450
# Saving snapshot 2
# in _end_epoch, epoch is: 451
# in _end_epoch, epoch is: 452
# in _end_epoch, epoch is: 453
# in _end_epoch, epoch is: 454
# in _end_epoch, epoch is: 455
# in _end_epoch, epoch is: 456
# Saving snapshot best
# 3545.3585719057833
# 3539.937118086839
# in _end_epoch, epoch is: 457
# in _end_epoch, epoch is: 458
# in _end_epoch, epoch is: 459
# in _end_epoch, epoch is: 460
# Saving snapshot 2
# in _end_epoch, epoch is: 461
# in _end_epoch, epoch is: 462
# in _end_epoch, epoch is: 463
# in _end_epoch, epoch is: 464
# in _end_epoch, epoch is: 465
# in _end_epoch, epoch is: 466
# in _end_epoch, epoch is: 467
# in _end_epoch, epoch is: 468
# in _end_epoch, epoch is: 469
# in _end_epoch, epoch is: 470
# Saving snapshot 2
# in _end_epoch, epoch is: 471
# in _end_epoch, epoch is: 472
# in _end_epoch, epoch is: 473
# in _end_epoch, epoch is: 474
# in _end_epoch, epoch is: 475
# in _end_epoch, epoch is: 476
# in _end_epoch, epoch is: 477
# in _end_epoch, epoch is: 478
# in _end_epoch, epoch is: 479
# in _end_epoch, epoch is: 480
# Saving snapshot 2
# in _end_epoch, epoch is: 481
# in _end_epoch, epoch is: 482
# in _end_epoch, epoch is: 483
# in _end_epoch, epoch is: 484
# in _end_epoch, epoch is: 485
# in _end_epoch, epoch is: 486
# in _end_epoch, epoch is: 487
# in _end_epoch, epoch is: 488
# in _end_epoch, epoch is: 489
# in _end_epoch, epoch is: 490
# Saving snapshot 2
# in _end_epoch, epoch is: 491
# in _end_epoch, epoch is: 492
# in _end_epoch, epoch is: 493
# in _end_epoch, epoch is: 494
# in _end_epoch, epoch is: 495
# in _end_epoch, epoch is: 496
# in _end_epoch, epoch is: 497
# in _end_epoch, epoch is: 498
# in _end_epoch, epoch is: 499
# in _end_epoch, epoch is: 500
# Saving snapshot 2
# in _end_epoch, epoch is: 501
# in _end_epoch, epoch is: 502
# in _end_epoch, epoch is: 503
# in _end_epoch, epoch is: 504
# in _end_epoch, epoch is: 505
# in _end_epoch, epoch is: 506
# in _end_epoch, epoch is: 507
# in _end_epoch, epoch is: 508
# in _end_epoch, epoch is: 509
# Saving snapshot best
# 3566.20432118178
# 3545.3585719057833
# in _end_epoch, epoch is: 510
# Saving snapshot 2
# in _end_epoch, epoch is: 511
# in _end_epoch, epoch is: 512
# in _end_epoch, epoch is: 513
# in _end_epoch, epoch is: 514
# in _end_epoch, epoch is: 515
# in _end_epoch, epoch is: 516
# in _end_epoch, epoch is: 517
# in _end_epoch, epoch is: 518
# in _end_epoch, epoch is: 519
# in _end_epoch, epoch is: 520
# Saving snapshot 2
# in _end_epoch, epoch is: 521
# in _end_epoch, epoch is: 522
# in _end_epoch, epoch is: 523
# in _end_epoch, epoch is: 524
# in _end_epoch, epoch is: 525
# in _end_epoch, epoch is: 526
# in _end_epoch, epoch is: 527
# in _end_epoch, epoch is: 528
# in _end_epoch, epoch is: 529
# in _end_epoch, epoch is: 530
# Saving snapshot 2
# in _end_epoch, epoch is: 531
# in _end_epoch, epoch is: 532
# in _end_epoch, epoch is: 533
# in _end_epoch, epoch is: 534
# Saving snapshot best
# 3632.0269151061557
# 3566.20432118178
# in _end_epoch, epoch is: 535
# in _end_epoch, epoch is: 536
# in _end_epoch, epoch is: 537
# in _end_epoch, epoch is: 538
# in _end_epoch, epoch is: 539
# in _end_epoch, epoch is: 540
# Saving snapshot 2
# in _end_epoch, epoch is: 541
# in _end_epoch, epoch is: 542
# in _end_epoch, epoch is: 543
# in _end_epoch, epoch is: 544
# in _end_epoch, epoch is: 545
# in _end_epoch, epoch is: 546
# in _end_epoch, epoch is: 547
# in _end_epoch, epoch is: 548
# in _end_epoch, epoch is: 549
# in _end_epoch, epoch is: 550
# Saving snapshot 2
# in _end_epoch, epoch is: 551
# in _end_epoch, epoch is: 552
# in _end_epoch, epoch is: 553
# in _end_epoch, epoch is: 554
# in _end_epoch, epoch is: 555
# in _end_epoch, epoch is: 556
# in _end_epoch, epoch is: 557
# in _end_epoch, epoch is: 558
# in _end_epoch, epoch is: 559
# in _end_epoch, epoch is: 560
# Saving snapshot 2
# in _end_epoch, epoch is: 561
# in _end_epoch, epoch is: 562
# in _end_epoch, epoch is: 563
# in _end_epoch, epoch is: 564
# in _end_epoch, epoch is: 565
# in _end_epoch, epoch is: 566
# in _end_epoch, epoch is: 567
# in _end_epoch, epoch is: 568
# in _end_epoch, epoch is: 569
# in _end_epoch, epoch is: 570
# Saving snapshot 2
# in _end_epoch, epoch is: 571
# in _end_epoch, epoch is: 572
# in _end_epoch, epoch is: 573
# in _end_epoch, epoch is: 574
# in _end_epoch, epoch is: 575
# in _end_epoch, epoch is: 576
# in _end_epoch, epoch is: 577
# in _end_epoch, epoch is: 578
# in _end_epoch, epoch is: 579
# in _end_epoch, epoch is: 580
# Saving snapshot 2
# in _end_epoch, epoch is: 581
# in _end_epoch, epoch is: 582
# in _end_epoch, epoch is: 583
# in _end_epoch, epoch is: 584
# in _end_epoch, epoch is: 585
# in _end_epoch, epoch is: 586
# in _end_epoch, epoch is: 587
# in _end_epoch, epoch is: 588
# in _end_epoch, epoch is: 589
# in _end_epoch, epoch is: 590
# Saving snapshot 2
# in _end_epoch, epoch is: 591
# in _end_epoch, epoch is: 592
# in _end_epoch, epoch is: 593
# in _end_epoch, epoch is: 594
# in _end_epoch, epoch is: 595
# in _end_epoch, epoch is: 596
# in _end_epoch, epoch is: 597
# in _end_epoch, epoch is: 598
# in _end_epoch, epoch is: 599
# in _end_epoch, epoch is: 600
# Saving snapshot 2
# in _end_epoch, epoch is: 601
# in _end_epoch, epoch is: 602
# in _end_epoch, epoch is: 603
# in _end_epoch, epoch is: 604
# in _end_epoch, epoch is: 605
# in _end_epoch, epoch is: 606
# in _end_epoch, epoch is: 607
# in _end_epoch, epoch is: 608
# in _end_epoch, epoch is: 609
# in _end_epoch, epoch is: 610
# Saving snapshot 2
# in _end_epoch, epoch is: 611
# in _end_epoch, epoch is: 612
# in _end_epoch, epoch is: 613
# in _end_epoch, epoch is: 614
# in _end_epoch, epoch is: 615
# in _end_epoch, epoch is: 616
# in _end_epoch, epoch is: 617
# in _end_epoch, epoch is: 618
# in _end_epoch, epoch is: 619
# in _end_epoch, epoch is: 620
# Saving snapshot 2
# in _end_epoch, epoch is: 621
# in _end_epoch, epoch is: 622
# in _end_epoch, epoch is: 623
# in _end_epoch, epoch is: 624
# in _end_epoch, epoch is: 625
# in _end_epoch, epoch is: 626
# in _end_epoch, epoch is: 627
# in _end_epoch, epoch is: 628
# in _end_epoch, epoch is: 629
# in _end_epoch, epoch is: 630
# Saving snapshot 2
# in _end_epoch, epoch is: 631
# in _end_epoch, epoch is: 632
# in _end_epoch, epoch is: 633
# in _end_epoch, epoch is: 634
# in _end_epoch, epoch is: 635
# in _end_epoch, epoch is: 636
# in _end_epoch, epoch is: 637
# in _end_epoch, epoch is: 638
# in _end_epoch, epoch is: 639
# in _end_epoch, epoch is: 640
# Saving snapshot 2
# in _end_epoch, epoch is: 641
# in _end_epoch, epoch is: 642
# in _end_epoch, epoch is: 643
# Saving snapshot best
# 3649.2897751498494
# 3632.0269151061557
# in _end_epoch, epoch is: 644
# in _end_epoch, epoch is: 645
# in _end_epoch, epoch is: 646
# in _end_epoch, epoch is: 647
# in _end_epoch, epoch is: 648
# in _end_epoch, epoch is: 649
# in _end_epoch, epoch is: 650
# Saving snapshot 2
# in _end_epoch, epoch is: 651
# in _end_epoch, epoch is: 652
# in _end_epoch, epoch is: 653
# in _end_epoch, epoch is: 654
# in _end_epoch, epoch is: 655
# in _end_epoch, epoch is: 656
# in _end_epoch, epoch is: 657
# in _end_epoch, epoch is: 658
# in _end_epoch, epoch is: 659
# in _end_epoch, epoch is: 660
# Saving snapshot 2
# in _end_epoch, epoch is: 661
# in _end_epoch, epoch is: 662
# in _end_epoch, epoch is: 663
# in _end_epoch, epoch is: 664
# in _end_epoch, epoch is: 665
# in _end_epoch, epoch is: 666
# in _end_epoch, epoch is: 667
# in _end_epoch, epoch is: 668
# in _end_epoch, epoch is: 669
# in _end_epoch, epoch is: 670
# Saving snapshot 2
# in _end_epoch, epoch is: 671
# in _end_epoch, epoch is: 672
# in _end_epoch, epoch is: 673
# in _end_epoch, epoch is: 674
# in _end_epoch, epoch is: 675
# in _end_epoch, epoch is: 676
# in _end_epoch, epoch is: 677
# in _end_epoch, epoch is: 678
# in _end_epoch, epoch is: 679
# in _end_epoch, epoch is: 680
# Saving snapshot 2
# in _end_epoch, epoch is: 681
# Saving snapshot best
# 3671.9547226210866
# 3649.2897751498494
# in _end_epoch, epoch is: 682
# in _end_epoch, epoch is: 683
# in _end_epoch, epoch is: 684
# in _end_epoch, epoch is: 685
# in _end_epoch, epoch is: 686
# in _end_epoch, epoch is: 687
# in _end_epoch, epoch is: 688
# in _end_epoch, epoch is: 689
# in _end_epoch, epoch is: 690
# Saving snapshot 2
# in _end_epoch, epoch is: 691
# in _end_epoch, epoch is: 692
# in _end_epoch, epoch is: 693
# in _end_epoch, epoch is: 694
# in _end_epoch, epoch is: 695
# in _end_epoch, epoch is: 696
# in _end_epoch, epoch is: 697
# in _end_epoch, epoch is: 698
# in _end_epoch, epoch is: 699
# in _end_epoch, epoch is: 700
# Saving snapshot 2
# in _end_epoch, epoch is: 701
# in _end_epoch, epoch is: 702
# in _end_epoch, epoch is: 703
# in _end_epoch, epoch is: 704
# in _end_epoch, epoch is: 705
# in _end_epoch, epoch is: 706
# in _end_epoch, epoch is: 707
# in _end_epoch, epoch is: 708
# in _end_epoch, epoch is: 709
# in _end_epoch, epoch is: 710
# Saving snapshot 2
# in _end_epoch, epoch is: 711
# in _end_epoch, epoch is: 712
# in _end_epoch, epoch is: 713
# in _end_epoch, epoch is: 714
# in _end_epoch, epoch is: 715
# in _end_epoch, epoch is: 716
# in _end_epoch, epoch is: 717
# in _end_epoch, epoch is: 718
# in _end_epoch, epoch is: 719
# in _end_epoch, epoch is: 720
# Saving snapshot 2
# in _end_epoch, epoch is: 721
# in _end_epoch, epoch is: 722
# in _end_epoch, epoch is: 723
# in _end_epoch, epoch is: 724
# in _end_epoch, epoch is: 725
# in _end_epoch, epoch is: 726
# in _end_epoch, epoch is: 727
# in _end_epoch, epoch is: 728
# in _end_epoch, epoch is: 729
# in _end_epoch, epoch is: 730
# Saving snapshot 2
# in _end_epoch, epoch is: 731
# in _end_epoch, epoch is: 732
# in _end_epoch, epoch is: 733
# in _end_epoch, epoch is: 734
# in _end_epoch, epoch is: 735
# in _end_epoch, epoch is: 736
# in _end_epoch, epoch is: 737
# in _end_epoch, epoch is: 738
# in _end_epoch, epoch is: 739
# in _end_epoch, epoch is: 740
# Saving snapshot 2
# in _end_epoch, epoch is: 741
# in _end_epoch, epoch is: 742
# in _end_epoch, epoch is: 743
# in _end_epoch, epoch is: 744
# in _end_epoch, epoch is: 745
# in _end_epoch, epoch is: 746
# in _end_epoch, epoch is: 747
# in _end_epoch, epoch is: 748
# in _end_epoch, epoch is: 749
# in _end_epoch, epoch is: 750
# Saving snapshot 2
# in _end_epoch, epoch is: 751
# in _end_epoch, epoch is: 752
# in _end_epoch, epoch is: 753
# in _end_epoch, epoch is: 754
# in _end_epoch, epoch is: 755
# ----------------------------------------------------------------------
# KeyboardInterrupt                    Traceback (most recent call last)
# <ipython-input-23-bf2592c3e1f6> in <module>
#      13     )
#      14     algorithm.to(ptu.device)
# ---> 15     algorithm.train(initial_epoch=0, epochs=1000)
#      16 else:
#      17 #     algorithm = TorchBatchRLAlgorithm()
#
# <ipython-input-15-daf106bfc266> in train(self, initial_epoch, epochs, dir_, exp_no)
#      47
#      48     def train(self, initial_epoch=0, epochs=None, dir_=None, exp_no=None):
# ---> 49         self._train(initial_epoch, epochs, dir_, exp_no)
#      50
#      51     def _train(self):
#
# <ipython-input-16-33fc8be59f6d> in _train(self, initial_epoch, epochs, dir_, exp_no)
#      94                     train_data = self.replay_buffer.random_batch(
#      95                         self.batch_size)
# ---> 96                     self.trainer.train(train_data)
#      97                 # # gt.stamp('training', unique=False)
#      98                 self.training_mode(False)
#
# ~/Desktop/rlkit/rlkit/torch/torch_rl_algorithm.py in train(self, np_batch)
#      74         self._num_train_steps += 1
#      75         batch = np_to_pytorch_batch(np_batch)
# ---> 76         self.train_from_torch(batch)
#      77
#      78     def get_diagnostics(self):
#
# ~/Desktop/rlkit/rlkit/torch/sac/sac.py in train_from_torch(self, batch)
#     110         """
#     111         new_obs_actions, policy_mean, policy_log_std, log_pi, *_ = self.policy(
# --> 112             obs, reparameterize=True, return_log_prob=True,
#     113         )
#     114         if self.use_automatic_entropy_tuning:
#
# ~/miniconda3/envs/tf_2/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/Desktop/rlkit/rlkit/torch/sac/policies.py in forward(self, obs, reparameterize, deterministic, return_log_prob)
#      85         if self.std is None:
#      86             log_std = self.last_fc_log_std(h)
# ---> 87             log_std = torch.clamp(log_std, LOG_SIG_MIN, LOG_SIG_MAX)
#      88             std = torch.exp(log_std)
#      89         else:
#
# KeyboardInterrupt:

# %%
# algorithm = TorchBatchRLAlgorithm2(
#         trainer=trainer,
#         exploration_env=expl_env,
#         evaluation_env=eval_env,
#         exploration_data_collector=expl_path_collector,
#         evaluation_data_collector=eval_path_collector,
#         replay_buffer=replay_buffer,
#         **variant['algorithm_kwargs']
#     )
# algorithm_ = copy.deepcopy(algorithm)

# %%
# epoch, algorithm = get_snapshot_3()

# %%
# algorithm.trainer.qf1.fcs[0].weight.data

# %%
# algorithm_.trainer.qf1.fcs[0].weight.data

# %%
# !rm logs/hopper/log2
# !>logs/hopper/log1.txt
# !rm results/hopper/*.pkl

# %%
# l = [('replay_buffer/size', '2000'), ('trainer/QF1 Loss', '22.540974'), ('trainer/QF2 Loss', '22.461214'), ('trainer/Policy Loss', '-5.3794346'), ('trainer/Q1 Predictions Mean', '-0.013111563'), ('trainer/Q1 Predictions Std', '0.006633578'), ('trainer/Q1 Predictions Max', '0.004102228'), ('trainer/Q1 Predictions Min', '-0.031592093'), ('trainer/Q2 Predictions Mean', '-0.0048158974'), ('trainer/Q2 Predictions Std', '0.0035169804'), ('trainer/Q2 Predictions Max', '0.0017666357'), ('trainer/Q2 Predictions Min', '-0.018819787'), ('trainer/Q Targets Mean', '4.6183643'), ('trainer/Q Targets Std', '1.043318'), ('trainer/Q Targets Max', '8.902103'), ('trainer/Q Targets Min', '0.38821536'), ('trainer/Log Pis Mean', '-5.393486'), ('trainer/Log Pis Std', '0.62483275'), ('trainer/Log Pis Max', '-3.6818123'), ('trainer/Log Pis Min', '-6.818282'), ('trainer/Policy mu Mean', '-8.544093e-05'), ('trainer/Policy mu Std', '0.0021631739'), ('trainer/Policy mu Max', '0.006241211'), ('trainer/Policy mu Min', '-0.008601425'), ('trainer/Policy log std Mean', '0.00043238376'), ('trainer/Policy log std Std', '0.0024977052'), ('trainer/Policy log std Max', '0.007946691'), ('trainer/Policy log std Min', '-0.007701927'), ('trainer/Alpha', '0.9997000694274902'), ('trainer/Alpha Loss', '-0.0'), ('exploration/num steps total', '2000'), ('exploration/num paths total', '14'), ('exploration/path length Mean', '142.85714285714286'), ('exploration/path length Std', '203.16174314459656'), ('exploration/path length Max', '635'), ('exploration/path length Min', '24'), ('exploration/Rewards Mean', '-0.6064347764021665'), ('exploration/Rewards Std', '0.7633642575876102'), ('exploration/Rewards Max', '2.8795207953591153'), ('exploration/Rewards Min', '-3.6407089958048813'), ('exploration/Returns Mean', '-86.63353948602385'), ('exploration/Returns Std', '113.0231192346682'), ('exploration/Returns Max', '-3.105460048148942'), ('exploration/Returns Min', '-353.8074739814667'), ('exploration/Actions Mean', '-0.007008702'), ('exploration/Actions Std', '0.6308291'), ('exploration/Actions Max', '0.99908894'), ('exploration/Actions Min', '-0.9995207'), ('exploration/Num Paths', '7'), ('exploration/Average Returns', '-86.63353948602385'), ('exploration/env_infos/final/reward_forward Mean', '0.19075281818276574'), ('explo
758082171038936'), ('evaluation/env_infos/initial/forward_reward Std', '0.12706800538907964'), ('evaluation/env_infos/initial/forward_reward Max', '0.10714505461736121'), ('evaluation/env_infos/initial/forward_reward Min', '-0.22169929465191252'), ('evaluation/env_infos/forward_reward Mean', '-0.001608596634589209'), ('evaluation/env_infos/forward_reward Std', '0.04913838565616579'), ('evaluation/env_infos/forward_reward Max', '0.9170830225171546'), ('evaluation/env_infos/forward_reward Min', '-1.13733215985436'), ('time/epoch (s)', '0'), ('time/total (s)', '70.16498186439276'), ('Epoch', '0')]

# %%
# for ll in l:
#     print(ll[0]+'\t'+ll[1])
#     print(ll[1])

# %%
# import rlkit

# %%
# d1 = {}
# i1 = 0
# for line in rlkit.core.tabulate.tabulate(l).split('\n'):
#     print(line)
#     print(i1)
#     print(l[i1][0])
#     print(l[i1][1])
#     d1[l[i1][0]] = l[i1][1]; i1+=1
# #     self.log(line, *args, **kwargs, file_name=file_name)
# d1

# %%
# print(len(l))

# %%
# !ls logs

# %%
# !rm *.pkl logs/*

# %%
# !ls | grep pkl

# %%
# !cat logs/2020-04-13\ 18\:51\:02.545425.txt

# %%
# f = open('temp3', 'a')

# %%
# f.write('Hi')

# %%
# f.flush()

# %%
# import os
# os.getpid()

# %%
# !cat temp3

# %%
# !rm temp*

# %%
# ckpt = torch.load('ckpt.pkl')

# %%
# device = torch.device("cuda:0")

# %%
# algorithm = ckpt['algorithm']

# %%
# initial_epoch

# %%
dir_ = 'results/hopper/'
f1 = dir_ + 'ckpt.pkl'
f2 = dir_ + 'ckpt-best.pkl'
x1 = torch.load(f1)
x2 = torch.load(f2)
x1

# %%
x2

# %%
x1['algorithm'].trainer.qf1.fc1 == x2['algorithm'].trainer.qf1.fc1

# %%
fc1 = x1['algorithm'].trainer.qf1.fcs[0]

# %%
fc2 = x2['algorithm'].trainer.qf1.fcs[0]

# %%
fc1.weight.data

# %%
fc2.weight.data

# %%
import torch

# %%
# algorithm.train(initial_epoch=initial_epoch, epochs = 2502)

# %%
type_ = 'ant'

# %%
a = None
with open('results/'+type_+'/tmp3/ckpt.pkl', 'rb') as f:
    a = torch.load(f)

# %%
b = None
with open('results/'+type_+'/ckpt.pkl', 'rb') as f:
    b = torch.load(f)

# %%
a['algorithm'].trainer.qf1.fcs[0].weight.data
# Out:
# tensor([[ 0.0764, -0.0760,  0.0869,  ...,  0.0151,  0.0483, -0.1715],
#         [-0.6630, -0.1337, -0.2489,  ...,  0.4513, -0.0044,  0.0391],
#         [-0.2671,  0.2481,  0.2976,  ..., -0.0115, -0.0393,  0.0302],
#         ...,
#         [-0.0379,  0.0194, -0.0876,  ..., -0.1665,  0.3195, -0.2556],
#         [ 0.0093, -0.1128, -0.1351,  ...,  0.1654,  0.0192, -0.1003],
#         [ 0.2320, -0.1157, -0.1732,  ...,  0.3441, -0.2284,  0.4927]],
#        device='cuda:0')

# %%
a['epoch']
# Out:
# 70

# %%
aa = a['algorithm']
aa2 = copy.deepcopy(aa)
bb = b['algorithm']

# %%
# aa.trainer.use_automatic_entropy_tuning

# %%
e, aa3 = get_snapshot_3()
# Out:
# in get_snapshot_3

# %%
def get_snapshot_3():
    print('in get_snapshot_3')
    ckpt = {}
    ckpt = torch.load('results/hopper/ckpt.pkl')
    # self = copy.deepcopy(ckpt['algorithm'])
    epoch = ckpt['epoch']
    return epoch, copy.deepcopy(ckpt['algorithm'])

# %%
# e

# %%
bb == aa
# Out:
# False

# %%
bb.trainer.use_automatic_entropy_tuning
# Out:
# True

# %%
aa.trainer.qf1.fcs[0].weight.data == aa2.trainer.qf1.fcs[0].weight.data
# Out:
# tensor([[True, True, True,  ..., True, True, True],
#         [True, True, True,  ..., True, True, True],
#         [True, True, True,  ..., True, True, True],
#         ...,
#         [True, True, True,  ..., True, True, True],
#         [True, True, True,  ..., True, True, True],
#         [True, True, True,  ..., True, True, True]], device='cuda:0')

# %%
aa3.trainer.qf1.fcs[0].weight.data
# Out:
# tensor([[-0.1598,  0.1912, -0.0921,  ..., -0.0361,  0.0528,  0.0564],
#         [ 0.0205,  0.1256, -0.0622,  ..., -0.0343,  0.0069, -0.0270],
#         [-0.0544, -0.0084,  0.0595,  ...,  0.0119,  0.1089, -0.0530],
#         ...,
#         [ 0.1002,  0.1294, -0.2716,  ..., -0.1797,  0.0309,  0.2037],
#         [ 0.1466,  0.1086,  0.1257,  ..., -0.0066, -0.0241, -0.0322],
#         [-0.0276,  0.0201,  0.1871,  ..., -0.0185, -0.0720,  0.0133]],
#        device='cuda:0')

# %%
aa.trainer.qf1.fcs[0].weight.data
# Out:
# tensor([[ 0.0764, -0.0760,  0.0869,  ...,  0.0151,  0.0483, -0.1715],
#         [-0.6630, -0.1337, -0.2489,  ...,  0.4513, -0.0044,  0.0391],
#         [-0.2671,  0.2481,  0.2976,  ..., -0.0115, -0.0393,  0.0302],
#         ...,
#         [-0.0379,  0.0194, -0.0876,  ..., -0.1665,  0.3195, -0.2556],
#         [ 0.0093, -0.1128, -0.1351,  ...,  0.1654,  0.0192, -0.1003],
#         [ 0.2320, -0.1157, -0.1732,  ...,  0.3441, -0.2284,  0.4927]],
#        device='cuda:0')

# %%
bb.trainer.qf1.fcs[0].weight.data
# Out:
# tensor([[-0.1598,  0.1912, -0.0921,  ..., -0.0361,  0.0528,  0.0564],
#         [ 0.0205,  0.1256, -0.0622,  ..., -0.0343,  0.0069, -0.0270],
#         [-0.0544, -0.0084,  0.0595,  ...,  0.0119,  0.1089, -0.0530],
#         ...,
#         [ 0.1002,  0.1294, -0.2716,  ..., -0.1797,  0.0309,  0.2037],
#         [ 0.1466,  0.1086,  0.1257,  ..., -0.0066, -0.0241, -0.0322],
#         [-0.0276,  0.0201,  0.1871,  ..., -0.0185, -0.0720,  0.0133]],
#        device='cuda:0')

# %%
aa2.trainer.qf1.fcs[0].weight.data
# Out:
# tensor([[ 0.0764, -0.0760,  0.0869,  ...,  0.0151,  0.0483, -0.1715],
#         [-0.6630, -0.1337, -0.2489,  ...,  0.4513, -0.0044,  0.0391],
#         [-0.2671,  0.2481,  0.2976,  ..., -0.0115, -0.0393,  0.0302],
#         ...,
#         [-0.0379,  0.0194, -0.0876,  ..., -0.1665,  0.3195, -0.2556],
#         [ 0.0093, -0.1128, -0.1351,  ...,  0.1654,  0.0192, -0.1003],
#         [ 0.2320, -0.1157, -0.1732,  ...,  0.3441, -0.2284,  0.4927]],
#        device='cuda:0')
